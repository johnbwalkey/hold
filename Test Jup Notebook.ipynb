# %% [markdown]
# My first notebook on xps

# %%
print ("hello")
# Out:
# hello

# %% [markdown]
# Checking new installs of VS code and Github on diff comp's and OS

# %%
print (2+4)
# Out:
# 6

# %%
print (2*12)
# Out:
# 24
