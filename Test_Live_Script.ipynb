# %% [markdown]
# ## This is just a test of Live Script
#
# I clicked TEXT button on toolbar to change cell type

# %%
x=0:5
# Out:
# x = 1x6
#      0     1     2     3     4     5

# %% [markdown]
# compute some functions

# %%
y=sqrt(x)
# Out:
# y = 1x6
#          0    1.0000    1.4142    1.7321    2.0000    2.2361

# %%
z=y+sin(x).^2
# Out:
# z = 1x6
#          0    1.7081    2.2410    1.7520    2.5728    3.1556

# %% [markdown]
# Make a plot

# %%
plot(x, z, ".r-")
# Out:
# <center><img src="data:image/png;base64,..." width="562" alt="figure_0.png"></center>

# %% [markdown]
# ## Different examples: vector

# %%
x=[1,2,3]
# Out:
# x = 1x3
#      1     2     3

# %%
x(1) % address the first element
# Out:
# ans = 1

# %% [markdown]
# Random matrix

# %%
y=rand(2,4)
# Out:
# y = 2x4
#     0.8147    0.1270    0.6324    0.2785
#     0.9058    0.9134    0.0975    0.5469

# %% [markdown]
# CAN just change values and run section to test !!!

# %%
y(2,3) % row by column
# Out:
# ans = 0.0975

# %%
y(1, :) %  first row all columns
# Out:
# ans = 1x4
#     0.8147    0.1270    0.6324    0.2785

# %% [markdown]
# ## Two percent signs becomes title

# %%
nx=31
# Out:
# nx = 31

# %%
x = linspace(0,1,nx) % build a vector (start, end, nx even spaced points)
# Out:
# x = 1x31
#          0    0.0333    0.0667    0.1000    0.1333    0.1667    0.2000    0.2333    0.2667    0.3000    0.3333    0.3667    0.4000    0.4333    0.4667    0.5000    0.5333    0.5667    0.6000    0.6333    0.6667    0.7000    0.7333    0.7667    0.8000    0.8333    0.8667    0.9000    0.9333    0.9667    1.0000

# %%
y = sin(2*pi*x);

# %% [markdown]
# can type %% Paraamters
#
#
# then on spacing line between code typ %% Calculations
#
#
# DIVIDES code into two cells !
#
#
# double click blue barber pole edge to evaluate
#
# ## visualize
#
#  $x$ is just italics
#
#
# calculate function ie. matlab equation = \$ expresson \$
#
#
#  $y=f(x)$ was   \$ y = f(x) then dollar sign

# %%
plot (x, y, 'LineWidth', 2)
grid on
set (gca, 'FontSize', 14, 'FontName', 'Times')
xlabel (' $x$ (m)','Interpreter', "latex")
ylabel (' $f(x)$ ','Interpreter', "latex")
# Out:
# <center><img src="data:image/png;base64,..." width="562" alt="figure_1.png"></center>

# %% [markdown]
# 2 lines is X-Y pairs

# %%
y2=cos(2*pi*x);
plot (x, y, x, y2,'LineWidth', 2)
grid on
set (gca, 'FontSize', 14, 'FontName', 'Times')
xlabel (' $x$ (m)','Interpreter', "latex")
ylabel (' $f(x)$ ','Interpreter', "latex")
legend (' $y$ ', ' $y_2$ ', 'interpreter', 'latex')
# Out:
# <center><img src="data:image/png;base64,..." width="562" alt="figure_2.png"></center>

# %% [markdown]
# could add Latex legend
#
#
# click export to save in another format (pdf, word, latex, including Jupyter)
#
# ## new idea

# %%
% do functions

# %% [markdown]
# ## Functions
#
# So ***f(x)*** shows us the function is called "***f***", and "***x***" goes **in**
#
#
# And we usually see what a function does with the input:
#
#
# ***f(x) = x******2*** shows us that function "***f***" takes "***x***" and squares it.

# %%
n=0;
for i=1:10
    f(i)=n;
    disp ("n" + n)
    disp (i)
    n=n+1;
end
# Out:
# n0
#      1
# n1
#      2
# n2
#      3
# n3
#      4
# n4
#      5
# n5
#      6
# n6
#      7
# n7
#      8
# n8
#      9
# n9
#     10

# %% [markdown]
# show pic
#
# <p style="text-align:left">
#    <img src="data:image/jpg;base64,..." width="338" alt="image_0.jpeg">
# </p>
